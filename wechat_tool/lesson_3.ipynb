# %% [markdown]
# # Work in progress...
# # Scan below QR code to become trainer's friend in WeChat!
# <img src='reference/WeChat_SamGu_QR.png' width=20% style="float: left;">
