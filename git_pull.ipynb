# %%
# !git pull
# Out:
# remote: Counting objects: 35, done.
# remote: Compressing objects: 100% (21/21), done.
# remote: Total 35 (delta 26), reused 23 (delta 14), pack-reused 0
# Unpacking objects: 100% (35/35), done.
# From https://github.com/telescopeuser/workshop_blog
#    de8d455..1614fa8  master     -> origin/master
# Updating de8d455..1614fa8
# Fast-forward
#  README.ipynb                                      |   20 +-
#  README.md                                         |   10 +-
#  wechat_tool/lesson_1.ipynb                        |   45 +-
#  wechat_tool/lesson_2.ipynb                        |   38 +-
#  wechat_tool/lesson_3.ipynb                        |   53 +-
#  wechat_tool/lesson_4.ipynb                        | 2366 +++++++++++----------
#  wechat_tool/lesson_5.ipynb                        | 2179 ++++++++++++++++++-
#  wechat_tool/reference/SampleVideo_360x240_1mb.mp4 |  Bin 0 -> 1053651 bytes
#  wechat_tool/reference/SampleVideo_360x240_2mb.mp4 |  Bin 0 -> 2100396 bytes
#  wechat_tool/reference/video_tn1.jpg               |  Bin 0 -> 231183 bytes
#  wechat_tool/reference/video_tn3.jpg               |  Bin 257830 -> 0 bytes
#  11 files changed, 3500 insertions(+), 1211 deletions(-)
#  create mode 100644 wechat_tool/reference/SampleVideo_360x240_1mb.mp4
#  create mode 100644 wechat_tool/reference/SampleVideo_360x240_2mb.mp4
#  create mode 100644 wechat_tool/reference/video_tn1.jpg
#  delete mode 100644 wechat_tool/reference/video_tn3.jpg

# %%
# !git pull
# Out:
# Already up to date.

# %%
# %load setup_cloud.py


# # Workshop Installation Guide

# # 如何使用和开发微信聊天机器人的系列教程
# # A workshop to develop & use an intelligent and interactive chat-bot in WeChat

# ### WeChat is a popular social media app, which has more than 800 million monthly active users.
# 
# <img src='http://www.kudosdata.com/wp-content/uploads/2016/11/cropped-KudosLogo1.png' width=30% style="float: right;">
# <img src='wechat_tool/reference/WeChat_SamGu_QR.png' width=10% style="float: right;">
# 
# ### http://www.KudosData.com
# 
# by: Sam.Gu@KudosData.com
# 
# 
# April 2017 ============= Scan the QR code to become trainer's friend in WeChat ===========>>

# # Option 1: Use Cloud Platform (Difficulty level: Easy, like being a boss)

# In[ ]:

get_ipython().system('python --version')


# In[ ]:

get_ipython().system('pip install -U html')


# In[ ]:

get_ipython().system('pip install -U pyqrcode')


# In[ ]:

get_ipython().system('pip install -U config')


# In[ ]:

get_ipython().system('pip install -U backports.tempfile')


# In[ ]:

get_ipython().system('mv docs org_docs')


# ### Download and install WeChat API-2

# In[ ]:

get_ipython().system('yes | pip uninstall itchat')
get_ipython().system('rm -rf ItChat')
get_ipython().system('git clone https://github.com/telescopeuser/ItChat.git')
get_ipython().system('cp -r ItChat/* .')
get_ipython().system('python setup.py install')


# ### Housekeeping after installation

# In[ ]:

get_ipython().system('rm -rf itchat')
get_ipython().system('rm -rf ItChat')
get_ipython().system('rm -rf wxpy')
get_ipython().system('rm -rf README*')
get_ipython().system('rm -rf LICENSE')
get_ipython().system('rm -rf MANIFEST*')
get_ipython().system('rm -rf mkdocs*')
get_ipython().system('rm -rf build')
get_ipython().system('rm -rf dist')
get_ipython().system('rm -rf docs*')
get_ipython().system('rm -rf requirements.txt')
get_ipython().system('rm -rf setup.py')
get_ipython().system('rm -rf *.egg-info')

get_ipython().system('mv org_docs docs')


get_ipython().system('pip install -U google-api-python-client')
get_ipython().system('pip install -U gTTS')
get_ipython().system('apt-get update -y')

# 21 Dec 2017: update: '--allow-unauthenticated', thanks to: MENG EN
# get_ipython().system('apt-get install libav-tools -y')
get_ipython().system('apt-get install libav-tools -y --allow-unauthenticated')

get_ipython().system('avconv -version')


# ### If above importing has no error, then installation is successful.

# # You are now ready to rock! Go to folder: workshop_blog/wechat_tool, open Notebook and follow...
# 
# <img src='./wechat_tool/reference/setup_ref_01.png' width=100% style="float: left;">

# In[ ]:

print('')
print('+-------------------------------------------------------------------------------------------------+')
print('| www.KudosData.com: Google Cloud Datalab Python 2 setup successful!                              |')
print('| You are now ready to rock! Go to folder: workshop_blog/wechat_tool, open Notebook and follow... |')
print('+-------------------------------------------------------------------------------------------------+')


# In[ ]:
# Out:
# Python 3.6.3 :: Anaconda, Inc.
# Collecting html
#   Downloading html-1.16.tar.gz
#     Complete output from command python setup.py egg_info:
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "/tmp/pip-build-fec_6eid/html/setup.py", line 12, in <module>
#         long_description = __doc__.decode('utf8'),
#     AttributeError: 'str' object has no attribute 'decode'
#
#     ----------------------------------------
# Command "python setup.py egg_info" failed with error code 1 in /tmp/pip-build-fec_6eid/html/
# Collecting pyqrcode
# Installing collected packages: pyqrcode
# Successfully installed pyqrcode-1.2.1
# Collecting config
#   Downloading config-0.3.9.tar.gz
# Building wheels for collected packages: config
#   Running setup.py bdist_wheel for config ... done
#   Stored in directory: /home/iss-user/.cache/pip/wheels/53/3d/4b/b65b93aeeb83b93dcc103f8addd3b4b7e5668496868c103b5a
# Successfully built config
# Installing collected packages: config
# Successfully installed config-0.3.9
# Collecting backports.tempfile
#   Downloading backports.tempfile-1.0-py2.py3-none-any.whl
# Collecting backports.weakref (from backports.tempfile)
#   Downloading backports.weakref-1.0.post1-py2.py3-none-any.whl
# Installing collected packages: backports.weakref, backports.tempfile
#   Found existing installation: backports.weakref 1.0rc1
#     Uninstalling backports.weakref-1.0rc1:
#       Successfully uninstalled backports.weakref-1.0rc1
# Successfully installed backports.tempfile-1.0 backports.weakref-1.0.post1
# mv: cannot stat 'docs': No such file or directory
# Cannot uninstall requirement itchat, not installed
# yes: standard output: Broken pipe
# Cloning into 'ItChat'...
# remote: Counting objects: 1483, done.
# remote: Total 1483 (delta 0), reused 0 (delta 0), pack-reused 1482
# Receiving objects: 100% (1483/1483), 928.69 KiB | 640.00 KiB/s, done.
# Resolving deltas: 100% (967/967), done.
# Traceback (most recent call last):
#   File "setup.py", line 9, in <module>
#     import itchat
#   File "/home/iss-user/Desktop/git/workshop_blog/itchat/__init__.py", line 2, in <module>
#     from .core import Core
#   File "/home/iss-user/Desktop/git/workshop_blog/itchat/core.py", line 3, in <module>
#     import requests
# ModuleNotFoundError: No module named 'requests'
# mv: cannot stat 'org_docs': No such file or directory
# Collecting google-api-python-client
#   Downloading google_api_python_client-1.6.4-py2.py3-none-any.whl (53kB)
#     100% |████████████████████████████████| 61kB 422kB/s ta 0:00:01
# Collecting httplib2<1dev,>=0.9.2 (from google-api-python-client)
#   Downloading httplib2-0.10.3.tar.gz (204kB)
#     100% |████████████████████████████████| 204kB 732kB/s ta 0:00:01
# Collecting oauth2client<5.0.0dev,>=1.5.0 (from google-api-python-client)
#   Downloading oauth2client-4.1.2-py2.py3-none-any.whl (99kB)
#     100% |████████████████████████████████| 102kB 2.9MB/s a 0:00:011
# Requirement already up-to-date: six<2dev,>=1.6.1 in /home/iss-user/anaconda3/envs/iss-env/lib/python3.6/site-packages (from google-api-python-client)
# Collecting uritemplate<4dev,>=3.0.0 (from google-api-python-client)
#   Downloading uritemplate-3.0.0-py2.py3-none-any.whl
# Collecting rsa>=3.1.4 (from oauth2client<5.0.0dev,>=1.5.0->google-api-python-client)
#   Downloading rsa-3.4.2-py2.py3-none-any.whl (46kB)
#     100% |████████████████████████████████| 51kB 3.2MB/s ta 0:00:01
# Collecting pyasn1-modules>=0.0.5 (from oauth2client<5.0.0dev,>=1.5.0->google-api-python-client)
#   Downloading pyasn1_modules-0.2.1-py2.py3-none-any.whl (60kB)
#     100% |████████████████████████████████| 61kB 2.8MB/s ta 0:00:011
# Collecting pyasn1>=0.1.7 (from oauth2client<5.0.0dev,>=1.5.0->google-api-python-client)
#   Downloading pyasn1-0.4.2-py2.py3-none-any.whl (71kB)
#     100% |████████████████████████████████| 71kB 8.1MB/s eta 0:00:01
# Building wheels for collected packages: httplib2
#   Running setup.py bdist_wheel for httplib2 ... done
#   Stored in directory: /home/iss-user/.cache/pip/wheels/ca/ac/5f/749651f7925b231103f5316cacca82a487810c22d30f011c0c
# Successfully built httplib2
# Installing collected packages: httplib2, pyasn1, rsa, pyasn1-modules, oauth2client, uritemplate, google-api-python-client
# Successfully installed google-api-python-client-1.6.4 httplib2-0.10.3 oauth2client-4.1.2 pyasn1-0.4.2 pyasn1-modules-0.2.1 rsa-3.4.2 uritemplate-3.0.0
# Collecting gTTS
#   Downloading gTTS-1.2.2.tar.gz
# Requirement already up-to-date: six in /home/iss-user/anaconda3/envs/iss-env/lib/python3.6/site-packages (from gTTS)
# Collecting requests (from gTTS)
#   Downloading requests-2.18.4-py2.py3-none-any.whl (88kB)
#     100% |████████████████████████████████| 92kB 865kB/s ta 0:00:011
# Collecting gtts_token (from gTTS)
#   Downloading gTTS-token-1.1.1.zip
# Requirement already up-to-date: certifi>=2017.4.17 in /home/iss-user/anaconda3/envs/iss-env/lib/python3.6/site-packages (from requests->gTTS)
# Collecting idna<2.7,>=2.5 (from requests->gTTS)
#   Downloading idna-2.6-py2.py3-none-any.whl (56kB)
#     100% |████████████████████████████████| 61kB 3.0MB/s ta 0:00:01
# Collecting urllib3<1.23,>=1.21.1 (from requests->gTTS)
#   Downloading urllib3-1.22-py2.py3-none-any.whl (132kB)
#     100% |████████████████████████████████| 133kB 692kB/s ta 0:00:01
# Collecting chardet<3.1.0,>=3.0.2 (from requests->gTTS)
#   Downloading chardet-3.0.4-py2.py3-none-any.whl (133kB)
#     100% |████████████████████████████████| 143kB 1.5MB/s ta 0:00:01
# Building wheels for collected packages: gTTS, gtts-token
#   Running setup.py bdist_wheel for gTTS ... done
#   Stored in directory: /home/iss-user/.cache/pip/wheels/ef/e7/2e/066d7be1514f7c7fd6c942f4d09ae5460f9a3125829782d03d
#   Running setup.py bdist_wheel for gtts-token ... done
#   Stored in directory: /home/iss-user/.cache/pip/wheels/a9/19/5d/2abe941153d0331bb7c2fbcd48ed8c36a67ca1d40bd572773e
# Successfully built gTTS gtts-token
# Installing collected packages: idna, urllib3, chardet, requests, gtts-token, gTTS
# Successfully installed chardet-3.0.4 gTTS-1.2.2 gtts-token-1.1.1 idna-2.6 requests-2.18.4 urllib3-1.22
# Reading package lists... Done
# W: chmod 0700 of directory /var/lib/apt/lists/partial failed - SetupAPTPartialDirectory (1: Operation not permitted)
# E: Could not open lock file /var/lib/apt/lists/lock - open (13: Permission denied)
# E: Unable to lock directory /var/lib/apt/lists/
# W: Problem unlinking the file /var/cache/apt/pkgcache.bin - RemoveCaches (13: Permission denied)
# W: Problem unlinking the file /var/cache/apt/srcpkgcache.bin - RemoveCaches (13: Permission denied)
# E: Could not open lock file /var/lib/dpkg/lock - open (13: Permission denied)
# E: Unable to lock the administration directory (/var/lib/dpkg/), are you root?
# ffmpeg version 2.8.11-0ubuntu0.16.04.1 Copyright (c) 2000-2017 the FFmpeg developers
# built with gcc 5.4.0 (Ubuntu 5.4.0-6ubuntu1~16.04.4) 20160609
# configuration: --prefix=/usr --extra-version=0ubuntu0.16.04.1 --build-suffix=-ffmpeg --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --cc=cc --cxx=g++ --enable-gpl --enable-shared --disable-stripping --disable-decoder=libopenjpeg --disable-decoder=libschroedinger --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmodplug --enable-libmp3lame --enable-libopenjpeg --enable-libopus --enable-libpulse --enable-librtmp --enable-libschroedinger --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxvid --enable-libzvbi --enable-openal --enable-opengl --enable-x11grab --enable-libdc1394 --enable-libiec61883 --enable-libzmq --enable-frei0r --enable-libx264 --enable-libopencv
# libavutil      54. 31.100 / 54. 31.100
# libavcodec     56. 60.100 / 56. 60.100
# libavformat    56. 40.101 / 56. 40.101
# libavdevice    56.  4.100 / 56.  4.100
# libavfilter     5. 40.101 /  5. 40.101
# libavresample   2.  1.  0 /  2.  1.  0
# libswscale      3.  1.101 /  3.  1.101
# libswresample   1.  2.101 /  1.  2.101
# libpostproc    53.  3.100 / 53.  3.100
# +-------------------------------------------------------------------------------------------------+
# | www.KudosData.com: Google Cloud Datalab Python 2 setup successful!                              |
# | You are now ready to rock! Go to folder: workshop_blog/wechat_tool, open Notebook and follow... |
# +-------------------------------------------------------------------------------------------------+
